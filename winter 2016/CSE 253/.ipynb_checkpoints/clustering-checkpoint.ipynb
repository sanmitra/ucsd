# %%
path = "C:\Users\oop\Desktop\Winter 2016\cse 250B\AwA-base\Animals_with_Attributes"

# %%
with open(path + "\predicate-matrix-continuous.txt") as f:
    lines = f.read().split("\n")

# %%
data = [map(float, filter(None, line.split(" "))) for line in lines if line]

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=10)

# %%
clusters = kmeans.fit_predict(data)
clusters
# Out:
# array([5, 9, 3, 2, 1, 1, 5, 1, 3, 1, 2, 2, 4, 6, 4, 5, 7, 3, 6, 7, 5, 8, 0,
#        3, 7, 2, 2, 6, 2, 8, 5, 4, 1, 8, 8, 3, 5, 0, 0, 5, 4, 0, 4, 2, 9, 1,
#        3, 8, 0, 3])

# %%
with open(path + "\classes.txt") as f:
    animals = f.read().split("\n")

# %%
for i in range(10):
    print "Cluster " + str(i) + " :\\\\"
    for index, cluster in enumerate(clusters):
        if cluster == i:
            print "\t" + animals[index].split("\t")[1] + ","
# Out:
# Cluster 0 :\\
# 	sheep,
# 	zebra,
# 	giant+panda,
# 	pig,
# 	cow,
# Cluster 1 :\\
# 	dalmatian,
# 	persian+cat,
# 	german+shepherd,
# 	siamese+cat,
# 	chihuahua,
# 	collie,
# Cluster 2 :\\
# 	beaver,
# 	skunk,
# 	mole,
# 	hamster,
# 	squirrel,
# 	rabbit,
# 	mouse,
# Cluster 3 :\\
# 	killer+whale,
# 	blue+whale,
# 	humpback+whale,
# 	seal,
# 	otter,
# 	walrus,
# 	dolphin,
# Cluster 4 :\\
# 	tiger,
# 	leopard,
# 	wolf,
# 	bobcat,
# 	lion,
# Cluster 5 :\\
# 	antelope,
# 	horse,
# 	moose,
# 	ox,
# 	giraffe,
# 	buffalo,
# 	deer,
# Cluster 6 :\\
# 	hippopotamus,
# 	elephant,
# 	rhinoceros,
# Cluster 7 :\\
# 	spider+monkey,
# 	gorilla,
# 	chimpanzee,
# Cluster 8 :\\
# 	fox,
# 	bat,
# 	rat,
# 	weasel,
# 	raccoon,
# Cluster 9 :\\
# 	grizzly+bear,
# 	polar+bear,

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt
from scipy.spatial.distance import pdist
from pylab import rcParams

# %matplotlib inline

# %%
diagram = dendrogram(linkage(data, method='average'), leaf_label_func=lambda id : animals[id].split("\t")[1], orientation='right')
rcParams['figure.figsize'] = 5, 10
plt.tight_layout()
plt.savefig("heirarch.png")

# %%
kmeans = KMeans(n_clusters=1)

# %%
kmeans.fit_predict([[-10], [-8], [0], [8], [10]])
# Out:
# array([0, 0, 0, 0, 0])

# %%
kmeans.cluster_centers_
# Out:
# array([[ 0.]])

# %%
−10, −8, 0, 8, 10
# Out:
#   File "<ipython-input-43-fb9bab44e964>", line 1
#     −10, −8, 0, 8, 10
#     ^
# SyntaxError: invalid syntax

# %%
import random

rcParams['figure.figsize'] = 15, 20

from sklearn.decomposition import PCA
pca = PCA(n_components=2)
data_pca = pca.fit_transform(data)

animal_names = [animal.split("\t")[1] for animal in animals if animal]

plt.scatter(data_pca[:, 0], data_pca[:, 1])

for label, x, y in zip(animal_names, data_pca[:, 0], data_pca[:, 1]):
    plt.annotate(label, xy = (x, y),
                 ha = random.choice(['right', 'left']),
                 fontsize=15)
plt.savefig("PCA.png")
plt.show()

# %%
import numpy as np
a = np.array([-10,5,20])

# %%
a.mean()
# Out:
# 2.6666666666666665

# %%
sum(a-a.mean())
# Out:
# 1.7763568394002505e-15

# %%
(a-a.mean()).sum()
# Out:
# 1.7763568394002505e-15

# %%
a - a.mean()
# Out:
# array([-5.66666667, -1.66666667,  7.33333333])

# %%
-5.67 + -1.6 + 7.33
# Out:
# 0.0600000000000005

# %%
(a-1).sum()
# Out:
# 5
